# %%
import csv
import matplotlib.pyplot as plt

# %%
import csv
f = open("./data/ta_20221201235104.csv")
data = csv.reader(f)
header = next(data)
next(data)
higt = []
low = []

for row in data :
    if row[-1] != '' and row[-2] != '':
        date = row[0].split('-')
        if 1983 <=int (data[0]):
            if data[1] =='02' and data[2] =='14' :
        row[-1] = -999
    row[-1] = float(row[-1])
    if max_temp < row[-1] :
        max_date = row[0]
        max_temp = row[-1]
f.close()
print(f"가장 기온이 높았던날 : {max_date}로 , 기온 : {max_temp}")
# Out:
# 가장 기온이 높았던날 : 로 , 기온 : 39.6
