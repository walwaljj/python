# %%
import matplotlib.pyplot as plt
import random
result = []
for i in range(13) :
    result.append(random.randint(1,1000))
print(sorted(result))
plt.boxplot(result)
plt.show()
# Out:
# [4, 125, 157, 161, 455, 526, 559, 666, 708, 873, 916, 976, 982]

# %%
import numpy as np
result = np.array(result)
print("1/4: "+str(np.percentile(result,75)))
# Out:
# 1/4: 873.0

# %%
import csv
f = open('./data/ta_20221201235104.csv')
data = csv.reader(f)
next(data)
dec = []
for row in data :
    month = row[1].split('-')[1]
    if row[-1] != '':
        if month =='12' :
            dec.append(float(row[-1]))
plt.boxplot(dec)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x257d2ce03a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x257d2ca6850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x257d2ce0550>],
#  'medians': [<matplotlib.lines.Line2D at 0x257d2ca6a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x257d2ca6dc0>],
#  'means': []}

# %%
np.percentile(dec,100)
# Out:
# 17.7

# %%
import csv
f = open('./data/ta_20221201235104.csv')
data = csv.reader(f)
next(data)
dec = []
aug = []
for row in data :
    month = row[1].split('-')[1]
    if row[-1] != '':
        if month =='12' :
            dec.append(float(row[-1]))
        if month =='08' :
            aug.append(float(row[-1]))


plt.boxplot(dec)
plt.boxplot(aug)
plt.show()
plt.boxplot([dec,aug])
plt.show()

# %%
import csv
f = open('./data/ta_20221201235104.csv')
data = csv.reader(f)
next(data)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]
for row in data :
    month = row[1].split('-')[1]
    if row[-1] != '':
        print(f"{row[1].split('-')[1]}, {float(row[-1])}")
        # month[int(row[1].split('-')[1])-1].append(float(row[-1]))
# Out:
# 10, 20.7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [35], line 10
#       8 if row[-1] != '':
#       9     print(f"{row[1].split('-')[1]}, {float(row[-1])}")
# ---> 10     month[int(row[1].split('-')[1])-1].append(float(row[-1]))
#
# IndexError: string index out of range
